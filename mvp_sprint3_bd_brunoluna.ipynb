# %% [markdown]
# <a href="https://colab.research.google.com/github/brunolunarj/MvpSprint3-BD/blob/main/mvp_sprint3_bd_brunoluna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MVP PUCRIO - Sprint 3 - Engenharia de Dados**
#
# ---

# %% [markdown]
# **Por Bruno de Amorim Luna**

# %% [markdown]
# ## 1 - Definição do Problema
#
#
#
# ---

# %% [markdown]
# O Departamento Estadual de Trânsito faz parte do Sistema Nacional de Trânsito (SNT) e é responsável no estado pelas atividades de trânsito estabelecidas pelo Código de Trânsito Brasileiro (CTB) e por normatização própria.
# São competências do Detran promover educação para o trânsito, planejar, coordenar, executar e controlar ações relacionadas à habilitação de condutores, documentação e serviços para veículos. Além disso, o órgão produz estatísticas de trânsito e gerencia a autuação e a arrecadação de multas.<br> <br>
# De modo geral, o CTB define que as infrações são divididas em quatro tipos, de acordo com a gravidade da conduta – quanto maior for o perigo da infração, maiores serão as consequências.
# No Código de Trânsito Brasileiro, estão previstos quatro tipos de infrações: leves, médias, graves e gravíssimas.
# Cada uma dessas infrações equivale a um número de pontos, que existem para punir o motorista que recebe multas em excesso.
# A soma desses pontos é computada na Carteira Nacional de Habilitação (CNH) de um motorista, sendo que estourar o limite pode trazer consequências graves a ele.
# No artigo 259 do CTB, está prevista a pontuação para cada uma das infrações. Vamos a elas:
#
#
#
# *   Infração leve: 3 pontos;
# *   Infração média: 4 pontos;
# *   Infração grave: 5 pontos;
# *   Infração gravíssima: 7 pontos.
#
# <br>
#
# Segundo o artigo 261 do CTB, se um motorista soma 20 pontos em um período de 12 meses, ele sofre a suspensão do direito de dirigir.Para poder voltar às ruas, ele precisa passar por um curso de reciclagem e também passar um período suspenso (que pode ir de um mês a um ano sem a CNH).<br>
# Estaremos analisando as multas infração no DF conforme sua gravidade, verificando quais os tipo mais frequentes e a região de mais frequência. Para isso, iremos montar uma estrutura de dados em nuvem com a ferramenta **Amazon AWS**, realizando o armazenamento e o ETL dos dados nesta estrutura.
#
# Com esse MVP desejamos responder as seguintes questões:
#
# *   Qual a infração que mais ocorreu?
# *   Qual o tipo de gravidade de infração teve mais multas aplicadas?
# *   Em que região ocorreram mais infrações?

# %% [markdown]
# ## 2 - Coleta de Dados
# ---
#
#
# **Detran DF - Dados de infrações de trânsito no DF em 07/2023**

# %% [markdown]
# Os dados aqui analisados foram retirados do **Portal do Dados Abertos do DF**,  onde podemos encontrar dados de: Infrações de Trânsito, cursos oferecidos pelo Detran/DF ao público, campanhas educativas de trânsito Detran-DF, sinalização vertical e horizontal por região administrativa nas vias urbanas, número de habilitados nos Distrito Federal nos últimos 10 anos, etc.
# Foi baixado do portal um arquivo csv, que será utilizado para carga no servidor AWS e análise.
# <br>
# http://www.dados.df.gov.br/group/mobilidade.<br>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3 - Modelagem
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Na modelagem acima, podemos verificar, que os dados serão tirados do banco de dados do DETRAN DF, e colocados no cloud da AWS, onde ficará hospedado inicialmente em um **bucket do S3**. Logo após, utilizaremos o **GLUE** para realização do **ETL**, extraindo os dados do bucket do S3, transformando o schema dos dados e realizando a carga no **Redshift**.

# %% [markdown]
# ## 4 - Tratamento dos dados no Cloud - Amazon AWS
# ---

# %% [markdown]
# A primeira coisa a se fazer é entrar no site da AWS, realizando login ou cadastrando uma conta Amazon, através do site abaixo:
# https://aws.amazon.com/pt/.

# %% [markdown]
# ### 4.1 - Importação dos dados o Amazon S3
# ---

# %% [markdown]
# Dentro do ambiente AWS, iremos na barra de pesquisa e procuraremos o serviço do S3, para fazer o upload do arquivo para o S3.
# Amazon S3 ou Amazon Simple Storage Service é um serviço oferecido pela Amazon Web Services que fornece armazenamento de objetos por meio de uma interface de serviço da web. O Amazon S3 usa a mesma infraestrutura de armazenamento escalável que a Amazon.com usa para executar sua rede de comércio eletrônico.
# Para fazer upload de seus dados (fotos, vídeos, documentos etc.) para o Amazon S3, primeiro é necessário criar um bucket do S3 em uma das Regiões da AWS.
# Um bucket é um contêiner para objetos armazenados no Amazon S3. Você pode armazenar qualquer número de objetos em um bucket e pode ter até 100 buckets na sua conta.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Na tela principal do S3, procure pelo botão **Criar um Bucket**, escolha um nome pro seu bucket, a região da AWS que deseja hospedar seus arquivos, na propriedade de objeto, selecione se quer ou não ACLs, neste caso iremos habilitar.
# Uma **lista de controle de acesso (ACL)** de rede permite ou não determinado tráfego de entrada ou de saída no nível da sub-rede. Você pode usar a ACL de rede padrão para a VPC ou pode criar uma ACL de rede personalizada para a VPC com regras semelhantes às regras dos grupos de segurança para adicionar mais uma camada de segurança à VPC.
# Nas opções seguintes, deixei tudo padrão, mas podem ser personalizados o versionamento, tags e criptografia. Depois basta clicar em **Criar Bucket**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Após criar o Bucket, vamos criar uma pasta ou mais para organizar o nosso container. Basta clicar em criar bucket, colocar um nome e escolher ou não uma criptografia. Entrando na pasta clicamos em carregar, para fazer o upload do arquivo base do nosso banco de dados, neste caso um arquivo CSV. Selecionando o aquivo, ou arrastando, basta clicar em carregar.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.2 - Extrair, transformar e carregar (ETL) - Amazon GLUE
# ---

# %% [markdown]
# O AWS Glue é uma plataforma de computação sem servidor orientada a eventos fornecida pela Amazon como parte do Amazon Web Services. É um serviço de computação que executa código em resposta a eventos e gerencia automaticamente os recursos de computação exigidos por esse código. Foi apresentado em agosto de 2017.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.3 - Data Warehouse - Amazon Redshift
# ---

# %% [markdown]
# O Amazon Redshift é um produto de data warehouse que faz parte da maior plataforma de computação em nuvem Amazon Web Services.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5 - Análise dos Dados
# ---

# %% [markdown]
# ### 5.1 - Qualidade de dados

# %% [markdown]
# A qualidade dos dados é muito  boa, não sendo necessários nenhum tipo de tratamento para a sua análise.
# Todos os dados foram tratados com string, com exceção o atributo data_infração que é do tipo data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 5.2 - Solução do problema

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
